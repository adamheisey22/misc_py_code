# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
mke_map = gpd.read_file(r'C:\Users\adamh\OneDrive - Marquette University\PYTHON\Python class examples\neighborhood.shx')
#zipfile = (r'C\Users\adamh\OneDrive - Marquette University\PYTHON\Python class examples\072230_Planimetric.gdb.zip')

#map = gpd.read_file(zipfile)

# %%
fig,ax = plt.subplots(figsize = (15,15))
mke_map.plot(ax=ax,alpha = 0.4, color= "grey")
# Out:
# <AxesSubplot:>
